# %% [markdown]
# <center>
#
# <h1> Solving a Logic Puzzle </h1>
# <h2> CS3100 Fall 2019 </h2>
# </center>

# %% [markdown]
# ## Review
#
# ### Previously
#
# * Logical Foundations
#   + First-order logic
#   + Definite clauses & Programs
#   + SLD resolution
#
# ### This lecture
#
# * Solving the Zerbra puzzle

# %% [markdown]
# ## Zebra Puzzle
#
# 1. There are five houses.
# 2. The Englishman lives in the red house.
# 3. The Spaniard owns the dog.
# 4. Coffee is drunk in the green house.
# 5. The Ukrainian drinks tea.
# 6. The green house is immediately to the right of the ivory house.
# 7. The Old Gold smoker owns snails.
# 8. Kools are smoked in the yellow house.
# 9. Milk is drunk in the middle house.
# 10. The Norwegian lives in the first house.
# 11. The man who smokes Chesterfields lives in the house next to the man with the fox.
# 12. Kools are smoked in the house next to the house where the horse is kept.
# 13. The Lucky Strike smoker drinks orange juice.
# 14. The Japanese smokes Parliaments.
# 15. The Norwegian lives next to the blue house.
#
# Now, who drinks water? Who owns the zebra?

# %% [markdown]
# ## Zebra Puzzle
#
# 1. There are **five** houses.
# 2. The **Englishman** lives in the **red** house.
# 3. The Spaniard owns the **dog**.
# 4. **Coffee** is drunk in the green house.
# 5. The Ukrainian drinks tea.
# 6. The green house is immediately to the **right of** the ivory house.
# 7. The **Old Gold** smoker owns snails.
# 8. Kools are smoked in the yellow house.
# 9. Milk is drunk in the **middle** house.
# 10. The Norwegian lives in the **first** house.
# 11. The man who smokes Chesterfields lives in the house next to the man with the fox.
# 12. Kools are smoked in the house **next to** the house where the horse is kept.
# 13. The Lucky Strike smoker drinks orange juice.
# 14. The Japanese smokes Parliaments.
# 15. The Norwegian lives **next to** the blue house.
#
# Now, who drinks water? Who owns the zebra?

# %% [markdown]
# ## Representing a house
#
# A house has 5 characteristics:
#
# 1. Nationality
# 2. Pet
# 3. Smoke
# 4. Drink
# 5. Colour
#
# We can define a function `house(Nationality,Pet,Smoke,Drink,Colour)` to represent this.
#
# We represent the row of houses as a 5-tuple `(H1,H2,H3,H4,H5)`.

# %% [markdown]
# ## Quiz
#
# What sort of a term is `house(Nationality,Pet,Smoke,Drink,Colour)`?
#
# 1. Number
# 2. Compound Term
# 3. Variable
# 4. Constant

# %% [markdown]
# ## Quiz
#
# What sort of a term is `house(Nationality,Pet,Smoke,Drink,Colour)`?
#
# 1. Number
# 2. Compound Term **✓**
# 3. Variable
# 4. Constant

# %% [markdown]
# ## Quiz
#
# What sort of a term is `(Nationality,Pet,Smoke,Drink,Colour)`?
#
# 1. Number
# 2. Compound Term
# 3. Variable
# 4. Constant

# %% [markdown]
# ## Quiz
#
# What sort of a term is `(Nationality,Pet,Smoke,Drink,Colour)`?
#
# 1. Number
# 2. Compound Term **✓**
# 3. Variable
# 4. Constant
#
# A tuple is a compond term with no explicit function symbol.

# %% [markdown]
# ## Define the house-existence facts
#
# * We want to convey this sort of house exists in this position.
#   + So define a predicate `exists` that captures this fact.

# %%
exists(A,(A,_,_,_,_)).
exists(A,(_,A,_,_,_)).
exists(A,(_,_,A,_,_)).
exists(A,(_,_,_,A,_)).
exists(A,(_,_,_,_,A)).
# Out:
# Added 5 clauses(s).

# %%
?- exists(h1,(h1,h2,h3,h4,h5)).
# Out:
# true.

# %%
?- exists(h2,(h1,h2,h3,h4,h5)).
# Out:
# true.

# %%
?- exists(h6,(h1,h2,h3,h4,h5)).
# Out:
# false.

# %% [markdown]
# ## Quiz
#
# Which of these queries returns true?
#
# 1. exists(dog,(fly,spider,bird,cat,dog)).
# 2. exists(dog,(fly,spider,bird,cat)).
# 3. exists(dog).
# 4. exists(house(english,red), (house(spanish,green), house(french,orange), house(dutch,yellow), house(german,blue), house(english,_)).

# %% [markdown]
# ## Quiz
#
# Which of these queries returns true?
#
# 1. exists(dog,(fly,spider,bird,cat,dog)). **yes**
# 2. exists(dog,(fly,spider,bird,cat)). **no**
# 3. exists(dog). **no**
# 4. exists(house(english,red), (house(spanish,green), house(french,orange), house(dutch,yellow), house(german,blue), house(english,_)). **yes**

# %% [markdown]
# ## rightOf
#
#     6. The green house is immediately to the right of the ivory house.

# %%
rightOf(A,B,(B,A,_,_,_)).
rightOf(A,B,(_,B,A,_,_)).
rightOf(A,B,(_,_,B,A,_)).
rightOf(A,B,(_,_,_,B,A)).

# %% [markdown]
# ## middle and first house
#
#     9. Milk is drunk in the middle house.

# %%
middleHouse(A,(_,_,A,_,_)).
# Out:
# Added 1 clauses(s).

# %% [markdown]
#     10. The Norwegian lives in the first house.

# %%
firstHouse(A,(A,_,_,_,_)).
# Out:
# Added 1 clauses(s).

# %% [markdown]
# ## nextTo
#
#     12. Kools are smoked in the house next to the house where the horse is kept.
#     15. The Norwegian lives next to the blue house.

# %%
nextTo(A,B,H) :- rightOf(A,B,H).
nextTo(A,B,(A,B,_,_,_)).
nextTo(A,B,(_,A,B,_,_)).
nextTo(A,B,(_,_,A,B,_)).
nextTo(A,B,(_,_,_,A,B)).
# Out:
# Added 5 clauses(s).

# %% [markdown]
# ## Express the puzzle as a Query

# %%
?- exists(house(british,_,_,_,red),Houses),
exists(house(spanish,dog,_,_,_),Houses),
exists(house(_,_,_,coffee,green),Houses),
exists(house(ukranian,_,_,tea,_),Houses),
rightOf(house(_,_,_,_,green),house(_,_,_,_,ivory),Houses),
exists(house(_,snail,oldgold,_,_),Houses),
exists(house(_,_,kools,_,yellow),Houses),
middleHouse(house(_,_,_,milk,_),Houses),
firstHouse(house(norwegian,_,_,_,_),Houses),
nextTo(house(_,_,chesterfields,_,_),house(_,fox,_,_,_),Houses),
nextTo(house(_,_,kools,_,_),house(_,horse,_,_,_),Houses),
exists(house(_,_,luckystrike,orangejuice,_),Houses),
exists(house(japanese,_,parliaments,_,_),Houses),
nextTo(house(norwegian,_,_,_,_),house(_,_,_,_,blue),Houses),
exists(house(WaterDrinker,_,_,water,_),Houses),
exists(house(ZebraOwner,zebra,_,_,_),Houses).
# Out:
# Houses = ,(house(norwegian, fox, kools, water, yellow), ,(house(ukranian, horse, chesterfields, tea, blue), ,(house(british, snail, oldgold, milk, red), ,(house(spanish, dog, luckystrike, orangejuice, ivory), house(japanese, zebra, parliaments, coffee, green))))), WaterDrinker = norwegian, ZebraOwner = japanese .

# %%
?- exists(house(british,_,_,_,red),Houses),
exists(house(spanish,dog,_,_,_),Houses) {40}.
# Out:
# Houses = ,(house(british, _2374, _2376, _2378, red), ,(house(spanish, dog, _2394, _2396, _2398), ,(_2438, ,(_2444, _2446)))) ;
# Houses = ,(house(british, _2374, _2376, _2378, red), ,(_2432, ,(house(spanish, dog, _2394, _2396, _2398), ,(_2444, _2446)))) ;
# Houses = ,(house(british, _2374, _2376, _2378, red), ,(_2432, ,(_2438, ,(house(spanish, dog, _2394, _2396, _2398), _2446)))) ;
# Houses = ,(house(british, _2374, _2376, _2378, red), ,(_2432, ,(_2438, ,(_2444, house(spanish, dog, _2394, _2396, _2398))))) ;
# Houses = ,(house(spanish, dog, _2394, _2396, _2398), ,(house(british, _2374, _2376, _2378, red), ,(_2438, ,(_2444, _2446)))) ;
# Houses = ,(_2426, ,(house(british, _2374, _2376, _2378, red), ,(house(spanish, dog, _2394, _2396, _2398), ,(_2444, _2446)))) ;
# Houses = ,(_2426, ,(house(british, _2374, _2376, _2378, red), ,(_2438, ,(house(spanish, dog, _2394, _2396, _2398), _2446)))) ;
# Houses = ,(_2426, ,(house(british, _2374, _2376, _2378, red), ,(_2438, ,(_2444, house(spanish, dog, _2394, _2396, _2398))))) ;
# Houses = ,(house(spanish, dog, _2394, _2396, _2398), ,(_2432, ,(house(british, _2374, _2376, _2378, red), ,(_2444, _2446)))) ;
# Houses = ,(_2426, ,(house(spanish, dog, _2394, _2396, _2398), ,(house(british, _2374, _2376, _2378, red), ,(_2444, _2446)))) ;
# Houses = ,(_2426, ,(_2432, ,(house(british, _2374, _2376, _2378, red), ,(house(spanish, dog, _2394, _2396, _2398), _2446)))) ;
# Houses = ,(_2426, ,(_2432, ,(house(british, _2374, _2376, _2378, red), ,(_2444, house(spanish, dog, _2394, _2396, _2398))))) ;
# Houses = ,(house(spanish, dog, _2394, _2396, _2398), ,(_2432, ,(_2438, ,(house(british, _2374, _2376, _2378, red), _2446)))) ;
# Houses = ,(_2426, ,(house(spanish, dog, _2394, _2396, _2398), ,(_2438, ,(house(british, _2374, _2376, _2378, red), _2446)))) ;
# Houses = ,(_2426, ,(_2432, ,(house(spanish, dog, _2394, _2396, _2398), ,(house(british, _2374, _2376, _2378, red), _2446)))) ;
# Houses = ,(_2426, ,(_2432, ,(_2438, ,(house(british, _2374, _2376, _2378, red), house(spanish, dog, _2394, _2396, _2398))))) ;
# Houses = ,(house(spanish, dog, _2394, _2396, _2398), ,(_2432, ,(_2438, ,(_2444, house(british, _2374, _2376, _2378, red))))) ;
# Houses = ,(_2426, ,(house(spanish, dog, _2394, _2396, _2398), ,(_2438, ,(_2444, house(british, _2374, _2376, _2378, red))))) ;
# Houses = ,(_2426, ,(_2432, ,(house(spanish, dog, _2394, _2396, _2398), ,(_2444, house(british, _2374, _2376, _2378, red))))) ;
# Houses = ,(_2426, ,(_2432, ,(_2438, ,(house(spanish, dog, _2394, _2396, _2398), house(british, _2374, _2376, _2378, red))))) .

# %% [markdown]
# ## Express the puzzle as a rule

# %%
puzzle(Houses) :- exists(house(british,_,_,_,red),Houses),
                  exists(house(spanish,dog,_,_,_),Houses),
                  exists(house(_,_,_,coffee,green),Houses),
                  exists(house(ukranian,_,_,tea,_),Houses),
                  rightOf(house(_,_,_,_,green),house(_,_,_,_,ivory),Houses),
                  exists(house(_,snail,oldgold,_,_),Houses),
                  exists(house(_,_,kools,_,yellow),Houses),
                  middleHouse(house(_,_,_,milk,_),Houses),
                  firstHouse(house(norwegian,_,_,_,_),Houses),
                  nextTo(house(_,_,chesterfields,_,_),house(_,fox,_,_,_),Houses),
                  nextTo(house(_,_,kools,_,_),house(_,horse,_,_,_),Houses),
                  exists(house(_,_,luckystrike,orangejuice,_),Houses),
                  exists(house(japanese,_,parliaments,_,_),Houses),
                  nextTo(house(norwegian,_,_,_,_),house(_,_,_,_,blue),Houses).
# Out:
# Added 1 clauses(s).

# %% [markdown]
# ## Express the puzzle as a rule
#
# Who is the zebra owner?

# %%
?- puzzle(Houses), exists(house(ZebraOwner,zebra,_,_,_),Houses).
# Out:
# Houses = ,(house(norwegian, fox, kools, _2532, yellow), ,(house(ukranian, horse, chesterfields, tea, blue), ,(house(british, snail, oldgold, milk, red), ,(house(spanish, dog, luckystrike, orangejuice, ivory), house(japanese, zebra, parliaments, coffee, green))))), ZebraOwner = japanese .

# %% [markdown]
# Who is the water drinker?

# %%
?- puzzle(Houses), exists(house(WaterDrinker,_,_,water,_),Houses).
# Out:
# Houses = ,(house(norwegian, fox, kools, water, yellow), ,(house(ukranian, horse, chesterfields, tea, blue), ,(house(british, snail, oldgold, milk, red), ,(house(spanish, dog, luckystrike, orangejuice, ivory), house(japanese, _G1055, parliaments, coffee, green))))), WaterDrinker = norwegian .

# %% [markdown]
# <center>
#
# <h1> Fin. </h1>
# </center>
